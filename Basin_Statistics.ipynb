# %%
import pandas as pd

# %%
# read in the values i want in to a dataframe
# make each value of the dataframe in to a string
# read in the master list
# drop each value in the master dataframe until you get the ones you want

# %%
df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/OLYMPEX.WRF_Master.Elwha_ranked.csv", header = None)

# %%
df_5 = df_ranked.iloc[18:,0]

# %%
df_5.values.tolist()
# Out:
# ['11/14/2015 6:00',
#  '11/1/2015 6:00',
#  '12/7/2015 12:00',
#  '12/11/2015 6:00',
#  '11/17/2015 12:00',
#  '11/14/2015 0:00',
#  '12/13/2015 12:00',
#  '1/22/2016 0:00',
#  '12/4/2015 0:00',
#  '12/8/2015 18:00',
#  '12/7/2015 6:00',
#  '12/11/2015 0:00',
#  '12/6/2015 0:00',
#  '11/1/2015 0:00',
#  '12/24/2015 12:00',
#  '12/24/2015 6:00',
#  '11/17/2015 18:00',
#  '11/13/2015 18:00',
#  '12/13/2015 6:00',
#  '12/3/2015 18:00',
#  '12/24/2015 0:00',
#  '1/13/2016 12:00',
#  '11/17/2015 6:00',
#  '1/21/2016 18:00',
#  '11/15/2015 12:00',
#  '11/13/2015 0:00',
#  '12/3/2015 12:00',
#  '12/18/2015 12:00',
#  '1/13/2016 6:00',
#  '12/20/2015 12:00',
#  '1/21/2016 12:00',
#  '12/10/2015 12:00',
#  '12/14/2015 12:00',
#  '12/14/2015 6:00',
#  '1/30/2016 12:00',
#  '11/15/2015 6:00',
#  '12/10/2015 18:00',
#  '12/14/2015 0:00',
#  '12/10/2015 6:00',
#  '12/7/2015 0:00',
#  '12/10/2015 0:00',
#  '1/18/2016 12:00',
#  '1/17/2016 12:00',
#  '1/17/2016 6:00',
#  '11/8/2015 12:00',
# ...

# %%
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/elwha_master_test.csv')

# %%
df = df_master.drop(df_5, axis= 1)

# %%
df
# Out:
#           XLONG       XLAT                                      geometry  \
# 0   -123.451904  47.672142   POINT (-123.451904296875 47.67214202880859)
# 1   -123.433470  47.672523  POINT (-123.4334716796875 47.67252349853516)
# 2   -123.415040  47.672900     POINT (-123.4150390625 47.67290115356445)
# 3   -123.489320  47.683790  POINT (-123.4893188476563 47.68378829956055)
# 4   -123.470890  47.684162  POINT (-123.4708862304688 47.68416213989258)
# ..          ...        ...                                           ...
# 433 -123.565280  48.116740  POINT (-123.5652770996094 48.11674118041992)
# 434 -123.546690  48.117134  POINT (-123.5466918945313 48.11713409423828)
# 435 -123.565860  48.129140   POINT (-123.5658569335938 48.1291389465332)
# 436 -123.547290  48.129543  POINT (-123.5472869873047 48.12954330444336)
# 437 -123.547880  48.141940  POINT (-123.5478820800781 48.14194107055664)
#
#      11/1/2015 12:00  11/14/2015 12:00  11/13/2015 12:00  11/13/2015 6:00  \
# ...

# %%
df_master.drop(['XLONG', 'XLAT', 'geometry'], axis= 1)
# Out:
#      11/1/2015 12:00  11/14/2015 12:00  11/13/2015 12:00  11/13/2015 6:00  \
# 0         108.897780         80.896370        142.941400        85.424280
# 1         113.911420         88.740300        142.237180        87.585620
# 2         117.815060         94.990990        145.030350        85.525990
# 3          87.400610         81.314230        117.060410        75.033340
# 4          94.463554         84.385740        136.433720        83.070800
# ..               ...               ...               ...              ...
# 433        16.181528         22.722322         18.383972         7.688064
# 434        14.783104         20.941380         16.622723         6.060389
# 435        16.193825         25.763454         23.472360         9.041970
# 436        15.212583         23.932611         21.507236         6.981587
# 437        14.609616         24.448872         20.762882         7.470565
#
#      1/22/2016 12:00  1/22/2016 6:00  12/6/2015 6:00  12/6/2015 12:00  \
# ...

# %%
df_sum = df_master.sum(axis= 1)

# %%
df_master['sum'] = df_sum

# %%
df_master.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.elwha_precip_5%.csv')

# %%
# top 10% of elwha

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/OLYMPEX.WRF_Master.Elwha_ranked.csv", header = None) # reads in csv with ranked values
df_list = df_ranked.iloc[36:,0] # change this number!!!! #chooses which values to drop in order to have the top whatever% of values desired
df_list.values.tolist() #changes the dataframe to a list
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/elwha_master_test.csv') # reads in the master wrf dataframe
df = df_master.drop(df_list, axis= 1) # drops the columns in the master dataset from the values of the list created before
#df.drop(['XLONG', 'XLAT', 'geometry'], axis= 1) #drops the xy columns to sum the rows
#df_sum = df.sum(axis= 1) #sums the rows
#df['sum'] = df_sum # creates a new column from the sums
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.elwha_precip_10%.csv') # saves to a csv

# %%
# top 25% of elwha

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/OLYMPEX.WRF_Master.Elwha_ranked.csv", header = None)
df_list = df_ranked.iloc[90:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/elwha_master_test.csv')
df = df_master.drop(df_list, axis= 1)
df.drop(['XLONG', 'XLAT', 'geometry'], axis= 1)
df_sum = df.sum(axis= 1)
df['sum'] = df_sum
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.elwha_precip_25%.csv')

# %%
# top 50% of elwha

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/OLYMPEX.WRF_Master.Elwha_ranked.csv", header = None)
df_list = df_ranked.iloc[179:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/elwha_master_test.csv')
df = df_master.drop(df_list, axis= 1)
df.drop(['XLONG', 'XLAT', 'geometry'], axis= 1)
df_sum = df.sum(axis= 1)
df['sum'] = df_sum
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.elwha_precip_50%.csv')

# %%
# west basins 5%

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/Olympics_west.side.basins_ranked.csv", header = None)
df_list = df_ranked.iloc[18:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/wrf_west.side.basins_test.csv')
df = df_master.drop(df_list, axis= 1)
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.west.basins_precip_5%.csv')

# %%
# west basins 10%

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/Olympics_west.side.basins_ranked.csv", header = None)
df_list = df_ranked.iloc[36:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/wrf_west.side.basins_test.csv')
df = df_master.drop(df_list, axis= 1)
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.west.basins_precip_10%.csv')

# %%
# west basins 25%

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/Olympics_west.side.basins_ranked.csv", header = None)
df_list = df_ranked.iloc[90:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/wrf_west.side.basins_test.csv')
df = df_master.drop(df_list, axis= 1)
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.west.basins_precip_25%.csv')

# %%
# west basins 50%

df_ranked = pd.read_csv("C:/Users/andrewm4/Downloads/MastersDatasets/Olympics_west.side.basins_ranked.csv", header = None)
df_list = df_ranked.iloc[179:,0] # change this number!!!!
df_list.values.tolist()
df_master = pd.read_csv('C:/Users/andrewm4/Downloads/MastersDatasets/wrf_west.side.basins_test.csv')
df = df_master.drop(df_list, axis= 1)
df.to_csv('/Users/andrewm4/Downloads/MastersDatasets/wrf_master.west.basins_precip_50%.csv')
